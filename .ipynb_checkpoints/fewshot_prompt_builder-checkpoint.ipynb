# %%
from prompts import (
    STATE_EXTRACTION_PROMPT,
    RESPONSE_GENERATION_PROMPT,
    DOMAIN_RECOGNITION_PROMPT
)

from multiwoz_utils.database import default_database
# results = default_database.query("hotel", {"area": "north", "parking": "yes"})
# print(results)

# %%
def process_examples(examples, input_keys, output_keys):
    output = "\n"
    for n, ex in enumerate(examples[-2:]):
        input_str = '\n'.join((f"{key if key != 'full_state' else 'state'}: {ex[key]}" for key in input_keys))
        output_str = '\n'.join((f"{key}: {ex[key]}" for key in output_keys))
        output += "---------------------" + \
                  f"Example {n}:\n" + \
                  f"{input_str}\n" + \
                  f"\n{output_str}\n"
    return output + "\n"

# %%
import pickle
from langchain.vectorstores import FAISS
from langchain.embeddings import HuggingFaceEmbeddings
from tqdm import tqdm

from multiwoz_utils.dialog_iterator import iterate_dialogues

from multiwoz_utils.data_loader import load_multiwoz

data = load_multiwoz()  # 默认加载 'train' split

# 设置参数
vec_file_path = "multiwoz-context-db.vec"
top_k = 5  # 检索候选数量

# 加载 embedding 模型
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2")

# 从本地加载 FAISS 向量库
with open(vec_file_path, "rb") as f:
    vector_store = pickle.load(f)

print("Loaded FAISS vector store from", vec_file_path)

last_dial_id = None
history = []

for it, turn in enumerate(tqdm(iterate_dialogues(data, default_database), desc="Retrieving", unit="turns")):
    dialog_id = turn['dialogue_id']

    if dialog_id != last_dial_id:
        history = []
        last_dial_id = dialog_id

    # 当前历史，不含当前 utterance
    history_text = "\n".join(history)

    # 相似性检索
    query_text = turn['page_content']
    results = vector_store.similarity_search(query_text, k=top_k)

    # 构造 few-shot 示例
    examples = [{
        'context': doc.metadata.get('context', ''),
        'state': doc.metadata.get('state', ''),
        'full_state': doc.metadata.get('full_state', ''),
        'response': doc.metadata.get('response', ''),
        'database': doc.metadata.get('database', ''),
        'domain': doc.metadata.get('domain', '')
    } for doc in results]

    fewshot_examples = process_examples(
        examples, ['context'], ['state']
    )

    # ✅ 用对话历史替换原来的 context
    final_prompt = STATE_EXTRACTION_PROMPT.format(
        fewshot_examples,
        history_text,
        turn['question'].strip()
    )

    print(final_prompt)
    print("==" * 50)

    # 更新对话历史
    history.append(f"Customer: {turn['question']}")
    history.append(f"Assistant: {turn['metadata']['response']}")

    if it == 5:
        break
# Out:
# Loaded FAISS vector store from multiwoz-context-db.vec
# Retrieving: 3turns [00:02,  1.67turns/s]
# Capture entity values from last utterance of the conversation according to examples.
# Focus only on the values mentioned in the last utterance.
# Capture pair "entity:value" with no spaces.
# Separate entity:value pairs by hyphens.
#
# Values that should be captured are:
#  - "pricerange": price range of the restaurant (cheap/moderate/expensive)
#  - "area": area where the restaurant is located (north/east/west/south/centre)
#  - "food": type of food the restaurant serves
#  - "name": name of the restaurant
#  - "bookday": day of the booking
#  - "booktime": time of the booking
#  - "bookpeople": how many people the booking is for
#
# Do not capture any other values!
# If a value is not specified, leave it empty.
#
# ------
#
# ---------------------Example 0:
# context: Customer: I would like to eat in the Center of town at a expensive place.
#
# state: {'restaurant': {'area': 'centre', 'pricerange': 'expensive'}}
# ---------------------Example 1:
# context: Customer: I want to find an expensive restaurant in the centre of town.
#
# state: {'restaurant': {'area': 'centre', 'pricerange': 'expensive'}}
#
#
# ---------
# Now complete the following example:
# input:
# Customer: i need a place to dine in the center thats expensive
# output:
# state:
# ====================================================================================================
# Capture entity values from last utterance of the conversation according to examples.
# Focus only on the values mentioned in the last utterance.
# Capture pair "entity:value" with no spaces.
# Separate entity:value pairs by hyphens.
#
# Values that should be captured are:
#  - "pricerange": price range of the restaurant (cheap/moderate/expensive)
#  - "area": area where the restaurant is located (north/east/west/south/centre)
#  - "food": type of food the restaurant serves
#  - "name": name of the restaurant
#  - "bookday": day of the booking
#  - "booktime": time of the booking
#  - "bookpeople": how many people the booking is for
#
# Do not capture any other values!
# If a value is not specified, leave it empty.
#
# ------
#
# ---------------------Example 0:
# context: Customer: Hi, I need a moderate price range restaurant in the centre of town.
# Assistant: There are 21 restaurants that are moderately priced in the centre of town. Do you have a food preference?
# Customer: British or European would be fine. May I book a table for 2 at 16:00 on a Wednesday and get a reference number please?
#
# state: {}
# ---------------------Example 1:
# context: Assistant: I'm sorry I do not show anything available. Would you like to try something else?
# Customer: Ok, how about an Italian restaurant?
# Assistant: There are 5 listings matching your criteria. Do you have a preference on the area?
# Customer: I do not have a preference of area as long as it's cheap. Please make a suggestion.
# Assistant: Ask is an Italian restaurant in the cheap priced category, and is the centre of town.
# Customer: Can I get the address and phone number?
#
# state: {'restaurant': {'name': 'ask'}}
#
#
# ---------
# Now complete the following example:
# input: Customer: i need a place to dine in the center thats expensive
# Assistant: I have several options for you; do you prefer African, Asian, or British food?
# Customer: Any sort of food would be fine, as long as it is a bit expensive. Could I get the phone number for your recommendation?
# output:
# state:
# ====================================================================================================
# Capture entity values from last utterance of the conversation according to examples.
# Focus only on the values mentioned in the last utterance.
# Capture pair "entity:value" with no spaces.
# Separate entity:value pairs by hyphens.
#
# Values that should be captured are:
#  - "pricerange": price range of the restaurant (cheap/moderate/expensive)
#  - "area": area where the restaurant is located (north/east/west/south/centre)
#  - "food": type of food the restaurant serves
#  - "name": name of the restaurant
#  - "bookday": day of the booking
#  - "booktime": time of the booking
#  - "bookpeople": how many people the booking is for
#
# Do not capture any other values!
# If a value is not specified, leave it empty.
#
# ------
#
# ---------------------Example 0:
# context: Customer: I'm looking for a particular restaurant called ask. Please give me information on that restaurant.
# Assistant: Ask is an italian place in the centre area, they are in the cheap price range. Can I help with anything else?
# Customer: Yes, I'd like to book a table for 1 at 17:15 on Wednesday. Can you do that?
#
# state: {'restaurant': {'bookday': 'wednesday', 'bookpeople': '1', 'booktime': '17:15'}}
# ---------------------Example 1:
# context: Assistant: I have several options for you; do you prefer African, Asian, or British food?
# Customer: Any sort of food would be fine, as long as it is a bit expensive. Could I get the phone number for your recommendation?
# Assistant: There is an Afrian place named Bedouin in the centre. How does that sound?
# Customer: Sounds good, could I get that phone number? Also, could you recommend me an expensive hotel?
# Assistant: Bedouin's phone is 01223367660. As far as hotels go, I recommend the University Arms Hotel in the center of town.
# Customer: Yes. Can you book it for me?
#
# state: {'hotel': {'name': 'university arms hotel', 'pricerange': 'expensive', 'type': 'hotel'}}
#
#
# ---------
# Now complete the following example:
# input: Customer: i need a place to dine in the center thats expensive
# Assistant: I have several options for you; do you prefer African, Asian, or British food?
# Customer: Any sort of food would be fine, as long as it is a bit expensive. Could I get the phone number for your recommendation?
# Assistant: There is an Afrian place named Bedouin in the centre. How does that sound?
# Customer: Sounds good, could I get that phone number? Also, could you recommend me an expensive hotel?
# output:
# state:
# ====================================================================================================
# Retrieving: 5turns [00:02,  2.05turns/s]
# Capture entity values from last utterance of the conversation according to examples.
# Focus only on the values mentioned in the last utterance.
# Capture pair "entity:value" with no spaces.
# Separate entity:value pairs by hyphens.
#
# Values that should be captured are:
#  - "pricerange": price range of the restaurant (cheap/moderate/expensive)
#  - "area": area where the restaurant is located (north/east/west/south/centre)
#  - "food": type of food the restaurant serves
#  - "name": name of the restaurant
#  - "bookday": day of the booking
#  - "booktime": time of the booking
#  - "bookpeople": how many people the booking is for
#
# Do not capture any other values!
# If a value is not specified, leave it empty.
#
# ------
#
# ---------------------Example 0:
# context: Customer: I'm looking for a hotel called Kirkwood House please.
# Assistant: I've located Kirkwood House. It's a guesthouse in the north. Would you like to book a room?
# Customer: May I please have the phone number for the hotel?
# Assistant: Absolutely. That number is 01223306283.
# Customer: I'm also looking for some places to go while I'm in town.
#
# state: {}
# ---------------------Example 1:
# context: Customer: What is the address to the hospital in Cambridge?
# Assistant: Address is Hills Road. Is there anything else?
# Customer: Can I also get their phone number please?
# Assistant: The phone number is 01223245151.
# Customer: Thank you! Can you also help me find a hotel?
#
# state: {'hotel': {'type': 'hotel'}}
#
#
# ---------
# Now complete the following example:
# input: Customer: i need a place to dine in the center thats expensive
# Assistant: I have several options for you; do you prefer African, Asian, or British food?
# Customer: Any sort of food would be fine, as long as it is a bit expensive. Could I get the phone number for your recommendation?
# Assistant: There is an Afrian place named Bedouin in the centre. How does that sound?
# Customer: Sounds good, could I get that phone number? Also, could you recommend me an expensive hotel?
# Assistant: Bedouin's phone is 01223367660. As far as hotels go, I recommend the University Arms Hotel in the center of town.
# Customer: Yes. Can you book it for me?
# output:
# state:
# ====================================================================================================
# Capture entity values from last utterance of the conversation according to examples.
# Focus only on the values mentioned in the last utterance.
# Capture pair "entity:value" with no spaces.
# Separate entity:value pairs by hyphens.
#
# Values that should be captured are:
#  - "pricerange": price range of the restaurant (cheap/moderate/expensive)
#  - "area": area where the restaurant is located (north/east/west/south/centre)
#  - "food": type of food the restaurant serves
#  - "name": name of the restaurant
#  - "bookday": day of the booking
#  - "booktime": time of the booking
#  - "bookpeople": how many people the booking is for
#
# Do not capture any other values!
# If a value is not specified, leave it empty.
#
# ------
#
# ---------------------Example 0:
# context: Assistant: There is the Gonville hotel in the centre and The Lensfield hotel in the south, both have free internet and parking. Would you like to book one of these?
# Customer: Could you give me more information the the Lensfield?
# Assistant: The lensfield hotel is an expensive 3 star hotel in the south area. Their address is 53-57 lensfield road. Would you like me to reserve a room for you?
# Customer: Yes please, book it for Saturday for 3 people for 3 nights.
# Assistant: I'm sorry, I was unable to reserve rooms for that day and length of stay. Would you like to try anything else?
# Customer: How about 2 nights? Would that work?
#
# state: {'hotel': {'bookstay': '2'}}
# ---------------------Example 1:
# context: Assistant: I have 2 on the north side that are in the moderate price range and 1 on the east side in the expensive range. Would you like to book one.
# Customer: Hmm. What do you what about 4 star hotels?
# Assistant: There are 5 guesthouses with 4 star ratings in Cambridge with moderate to cheap price ranges. Would you like more information?
# Customer: Well, I'd like to book one. I don't think it matters which one.
# Assistant: What dates would you like to book the room for?
# Customer: I need it for two nights starting on Saturday.
#
# state: {'hotel': {'bookday': 'saturday', 'bookstay': '2'}}
#
#
# ---------
# Now complete the following example:
# input: Customer: i need a place to dine in the center thats expensive
# Assistant: I have several options for you; do you prefer African, Asian, or British food?
# Customer: Any sort of food would be fine, as long as it is a bit expensive. Could I get the phone number for your recommendation?
# Assistant: There is an Afrian place named Bedouin in the centre. How does that sound?
# Customer: Sounds good, could I get that phone number? Also, could you recommend me an expensive hotel?
# Assistant: Bedouin's phone is 01223367660. As far as hotels go, I recommend the University Arms Hotel in the center of town.
# Customer: Yes. Can you book it for me?
# Assistant: Sure, when would you like that reservation?
# Customer: i want to book it for 2 people and 2 nights starting from saturday.
# output:
# state:
# ====================================================================================================
# Capture entity values from last utterance of the conversation according to examples.
# Focus only on the values mentioned in the last utterance.
# Capture pair "entity:value" with no spaces.
# Separate entity:value pairs by hyphens.
#
# Values that should be captured are:
#  - "pricerange": price range of the restaurant (cheap/moderate/expensive)
#  - "area": area where the restaurant is located (north/east/west/south/centre)
#  - "food": type of food the restaurant serves
#  - "name": name of the restaurant
#  - "bookday": day of the booking
#  - "booktime": time of the booking
#  - "bookpeople": how many people the booking is for
#
# Do not capture any other values!
# If a value is not specified, leave it empty.
#
# ------
#
# ---------------------Example 0:
# context: Assistant: Please show me a moderately priced hotel nearby, and please make sure it includes free wifi and parking.
# Customer: I need a moderately priced hotel with free parking and wifi.
# Assistant: I RECOMMEND acorn guest house
# Customer: That sounds good. please book it for 6 people and 5 nights starting from thursday.
# Assistant: Ok, I've made the booking for you. Your reference number is : UZ1KFAAI .
# Customer: that is all i needed for now. have a great day
#
# state: {}
# ---------------------Example 1:
# context: Assistant: How about Hobsons House? It is a moderately priced guesthouse in the west end.
# Customer: Does that place have free wifi?
# Assistant: Yes the place provides free wifi.
# Customer: Thank you, can you book me for 7 people and two nights, beginning on Sunday? May I also get a reference number?
# Assistant: Your booking was successful and reference number is Q1P81Y9Z . Can I assist you with anything else?
# Customer: No thanks, that is all.
#
# state: {}
#
#
# ---------
# Now complete the following example:
# input: Customer: i need a place to dine in the center thats expensive
# Assistant: I have several options for you; do you prefer African, Asian, or British food?
# Customer: Any sort of food would be fine, as long as it is a bit expensive. Could I get the phone number for your recommendation?
# Assistant: There is an Afrian place named Bedouin in the centre. How does that sound?
# Customer: Sounds good, could I get that phone number? Also, could you recommend me an expensive hotel?
# Assistant: Bedouin's phone is 01223367660. As far as hotels go, I recommend the University Arms Hotel in the center of town.
# Customer: Yes. Can you book it for me?
# Assistant: Sure, when would you like that reservation?
# Customer: i want to book it for 2 people and 2 nights starting from saturday.
# Assistant: Your booking was successful. Your reference number is FRGZWQL2 . May I help you further?
# Customer: That is all I need to know. Thanks, good bye.
# output:
# state:
# ====================================================================================================
